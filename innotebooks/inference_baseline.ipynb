# %% [markdown]
# <a href="https://colab.research.google.com/github/MarceloGMW/humidity-detection-aeco/blob/main/innotebooks/inference_baseline.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Baseline Inference Notebook
Notebook para ejecutar inferencia usando los pesos entrenados de YOLO sobre el dataset de humedades.
