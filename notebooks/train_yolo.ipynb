# %% [markdown]
# <a href="https://colab.research.google.com/github/MarceloGMW/humidity-detection-aeco/blob/main/notebooks/train_yolo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# YOLO Training Notebook
Notebook para entrenar el modelo YOLO sobre el dataset de humedades.
